# %% [markdown]
# <a href="https://colab.research.google.com/github/thisisme-shivam/AV-Hall-Booking-Android/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['ENV']="DEV"
#os.environ['MATRICE_SECRET_ACCESS_KEY'] = "" #Enter Matrice Secret Access Key
#os.environ['MATRICE_ACCESS_KEY_ID'] = "" #Enter Matrice Access Key

# %%
import sys
import os
parent_dir = os.path.abspath("..")
sys.path.append(parent_dir)
print(parent_dir)
from matrice_sdk.matrice import Session
from matrice_sdk.dataset import Dataset
import pprint
# Out:
# /code/python_repos/python_sdk/src

# %%
import yaml
with open('/code/test_configs/dev_test.yaml', 'r') as fp:
    test_config = yaml.safe_load(fp)

print(test_config)

project_id = test_config['project_id'] #Enter project_id

S = Session(project_id=project_id)
# Out:
# {'project_id': '660c0aeb22609a0124e34022', 's3_dataset_url': 'https://s3.us-west-2.amazonaws.com/testing.resources/datasets/imagenet-samples/vehicle-c10-10.tar.gz', 's3_dataset_name': 'vehicle-c10-10-sdk'}

# %% [markdown]
# **Create new Dataset**

# %%
dataset_name = test_config['s3_dataset_name']
dataset_url = test_config['s3_dataset_url']
is_unlabeled = False
source = "url"
dataset_type = "classification"
dataset_description = "Creating a new dataset using python-SDK"
version_description = "This verison is created using python-SDK"

resp, error, message = D.create_dataset(
    dataset_name=dataset_name,
    is_unlabeled=is_unlabeled,
    source=source,
    source_url=dataset_url,
    is_public=False,
    dataset_type=dataset_type,
    dataset_description=dataset_description,
    version_description=version_description
)

print("Message: ", message)
print("Error: ", error)
print("Response: ")
pprint.pprint(resp)
# Out:
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Message:  An error occured while trying to create new dataset
# Error:  Subscription expired
# Response:
# None

# %%
D = Dataset(S, '660f64f26286fef3f351a18c')

# %% [markdown]
# **GET Requests to Be-Dataset from Python-SDK**

# %%
resp, error, message = D.list_datasets()
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)
# Out:
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Message: Dataset list fetched successfully
# Error: None
# Response:
# {'items': [{'_id': '6620f84ea8cda28d7cf217f8',
#             '_idDatasetVersion': '000000000000000000000000',
#             '_idProject': '660c0aeb22609a0124e34022',
#             'allVersions': ['v1.0', 'v1.1'],
#             'createdAt': '2024-04-18T10:39:10.7Z',
#             'deploymentsCreated': 0,
#             'latestVersion': 'v1.1',
#             'modelsCreated': 0,
#             'name': 'new_deep_fashion',
#             'stats': {'test': 34093,
#                       'total': 113646,
#                       'train': 45460,
#                       'unassigned': 0,
#                       'val': 34093},
#             'status': 'processed',
#             'type': 'detection',
#             'updatedAt': '2024-04-18T11:55:36.378Z'},
#            {'_id': '6620ddf1a8cda28d7cf217f7',
# ...

# %%
resp, error, message = D.list_complete_dataset()
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)
# Out:
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Message: Completed dataset list fetched successfully
# Error: None
# Response:
# {'items': [{'_id': '6620f84ea8cda28d7cf217f8',
#             'allVersions': ['v1.0', 'v1.1'],
#             'disabledVersions': None,
#             'latestVersion': 'v1.1',
#             'name': 'new_deep_fashion',
#             'stats': [{'classStat': {'long sleeve dress': {'test': 0,
#                                                            'total': 9384,
#                                                            'train': 7907,
#                                                            'unassigned': 0,
#                                                            'val': 1477},
#                                      'shorts': {'test': 0,
#                                                 'total': 40783,
#                                                 'train': 36616,
# ...

# %%
dataset_version = 'v1.0'
resp, error, message = D.get_summary(dataset_version=dataset_version)
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)
# Out:
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Message: Could not fetch dataset summary
# Error: Subscription expired
# Response:
# None

# %%
resp, error, message = D.get_dataset()
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)
# Out:
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Message: Dataset fetched successfully
# Error: None
# Response:
# {'_id': '660f64f26286fef3f351a18c',
#  '_idDatasetVersion': '000000000000000000000000',
#  '_idProject': '660c0aeb22609a0124e34022',
#  'allVersions': ['v1.0', 'v1.1'],
#  'bucketAlias': '',
#  'createdAt': '2024-04-05T02:41:54.068Z',
#  'credentialAlias': '',
#  'datasetDesc': '',
#  'deploymentsCreated': 0,
#  'disabledVersions': None,
#  'isPublic': False,
#  'latestVersion': 'v1.1',
#  'modelsCreated': 0,
#  'name': 'deep-fashion-1',
#  's3DatasetBaseURL': 'https://s3.amazonaws.com/dev.dataset.extract',
#  'startIndex': 1000000,
#  'stats': [{'classStat': {'long sleeve dress': {'test': 0,
#                                                 'total': 9384,
#                                                 'train': 7907,
#                                                 'unassigned': 0,
# ...

# %%
resp, error, message = D.get_categories(dataset_version=dataset_version)
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)
# Out:
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Message: Could not fetch dataset categories
# Error: Subscription expired
# Response:
# None

# %%
resp, error, message = D.list_items_V2(dataset_version=dataset_version)
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)
# Out:
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Message: Could not fetch dataset items
# Error: Subscription expired
# Response:
# None

# %%
resp, error, message = D.list_items(dataset_version=dataset_version)
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)
# Out:
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Message: Could not fetch dataset items
# Error: Subscription expired
# Response:
# None

# %%
resp, error, message = D.get_processed_versions()
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)
# Out:
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Message: Processed versions fetched successfully
# Error: None
# Response:
# [{'_id': '660d00cb2410a0aa7cece9db',
#   '_idProject': '660c0aeb22609a0124e34022',
#   'allVersions': ['v1.0'],
#   'createdAt': '2024-04-03T07:10:03.14Z',
#   'disabledVersions': None,
#   'latestVersion': 'v1.0',
#   'name': 'df-2',
#   'processedVersions': ['v1.0'],
#   'stats': [{'classStat': {'long sleeve dress': {'test': 0,
#                                                  'total': 28,
#                                                  'train': 28,
#                                                  'unassigned': 0,
#                                                  'val': 0},
#                            'long sleeve outwear': {'test': 0,
#                                                    'total': 12,
#                                                    'train': 12,
# ...

# %% [markdown]
# **Splitting a Dataset**

# %%
old_dataset_version = 'v1.0'
new_dataset_version = 'v1.1'
is_random_split = True
train_num=738
val_num=105
test_num=210
transfers=[{"source":"","destination":"","transferAmount":1}]
new_version_description = 'Dataset splitted using Python-SDK'

resp, error, message = D.split_data(
    old_dataset_version=old_dataset_version,
    new_dataset_version=new_dataset_version,
    is_random_split=is_random_split,
    train_num=train_num,
    val_num=val_num,
    test_num=test_num,
    transfers=transfers,
    new_version_description=new_version_description
)

print("Message: ", message)
print("Error: ", error)
print("Response: ")
pprint.pprint(resp)
# Out:
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Sending request
# Getting Auth bearer token...
# Setting bearer token...
# Message:  An error occured while trying to split the data.
# Error:  Subscription expired
# Response:
# None

# %% [markdown]
# **Rename Dataset**

# %%
updated_name = 'SDK-dataset-test'

resp, error, message = D.update_dataset(updated_name=updated_name)
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)

# %% [markdown]
# **DELETE Requests to Be-Dataset from Python-SDK**

# %%
dataset_version = 'v1.0'
dataset_item_ids = ['65dd8ef05df9b3f72bd4b256', '65dd8ef05df9b3f72bd4b257', '65dd8ef05df9b3f72bd4b258']

resp, error, message = D.delete_dataset_item_classification(dataset_version=dataset_version, dataset_item_ids=dataset_item_ids)
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)

# %%
dataset_version = 'v1.0'
dataset_item_ids = ['65ddc738f820f0948bdd25da', '65ddc738f820f0948bdd25db', '65ddc738f820f0948bdd25dc']

resp, error, message = D.delete_dataset_item_detection(dataset_version=dataset_version, dataset_item_ids=dataset_item_ids)
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)

# %%
dataset_version = 'v1.1'

resp, error, message = D.delete_version(dataset_version=dataset_version)
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)

# %%
resp, error, message = D.delete_dataset()
print("Message:", message)
print("Error:", error)
print("Response:")
pprint.pprint(resp)
